'z': 0.2}], 'loc': 'servingroom'}, {'description': 'table for serving', 'id': 'servingtable|3', 'assetId': 'stable3', 'children': [], 'position': {'x': 0.538154035196955, 'z': 0.5313221740512857}, 'polygon': [{'x': 0.8763080703939101, 'z': 0.2}, {'x': 0.8763080703939101, 'z': 0.8626443481025714}, {'x': 0.2, 'z': 0.8626443481025714}, {'x': 0.2, 'z': 0.2}, {'x': 0.8763080703939101, 'z': 0.2}], 'loc': 'servingroom'}]}

# %%
import random
from shapely.geometry import box, Polygon, LineString, Point
import numpy as np
import matplotlib.pyplot as plt
import json
# from google.colab import files

# Function to draw polygons on the grid
def draw_polygon_on_grid(polygon, grid, value, min_x, min_z, resolution):
    exterior_coords = list(polygon.exterior.coords)
    for i in range(len(exterior_coords) - 1):
        x1, z1 = exterior_coords[i]
        x2, z2 = exterior_coords[i + 1]
        grid_x1, grid_z1 = world_to_grid(x1, z1, min_x, min_z, resolution)
        grid_x2, grid_z2 = world_to_grid(x2, z2, min_x, min_z, resolution)
        draw_line(grid, grid_x1, grid_z1, grid_x2, grid_z2, value)

# Function to convert world coordinates to grid indices
def world_to_grid(x, z, min_x, min_z, resolution):
    grid_x = round((x - min_x) / resolution)
    grid_z = round((z - min_z) / resolution)
    return grid_x, grid_z

# Function to draw a line on the grid with a specific value
def draw_line(grid, x1, z1, x2, z2, value):
    num_steps = max(abs(x2 - x1), abs(z2 - z1))
    for step in range(num_steps + 1):
        inter_x = int(x1 + step * (x2 - x1) / num_steps)
        inter_z = int(z1 + step * (z2 - z1) / num_steps)
        grid[inter_x, inter_z] = value

# Function to update the occupancy grid with rectangles
def update_occupancy_grid_with_rectangles(occupancy_grid, rectangle, min_x, min_z, resolution, val):
    # Get the bounding box of the rectangle
    min_x_rect, min_z_rect, max_x_rect, max_z_rect = rectangle.bounds

    # Calculate grid indices for the bounding box
    grid_min_x, grid_min_z = world_to_grid(min_x_rect, min_z_rect, min_x, min_z, resolution)
    grid_max_x, grid_max_z = world_to_grid(max_x_rect, max_z_rect, min_x, min_z, resolution)

    # Iterate over all the grid cells within the bounding box
    for grid_x in range(grid_min_x, grid_max_x + 1):
        for grid_z in range(grid_min_z, grid_max_z + 1):
            world_x = min_x + grid_x * resolution
            world_z = min_z + grid_z * resolution
            point = Point(world_x, world_z)

            # Check if the point is inside the rectangle
            if rectangle.contains(point) or rectangle.touches(point):
                occupancy_grid[grid_x, grid_z] = val

def get_occupancy_grid(kitchen, serving_room):
  # Convert to Shapely Polygons
  kitchen_polygon = Polygon([(point['x'], point['z']) for point in kitchen])
  serving_room_polygon = Polygon([(point['x'], point['z']) for point in serving_room])

  # Define the resolution of the grid (e.g., each cell is 0.1 units)
  resolution = 0.1

  # Merge the two room points
  all_points = kitchen + serving_room

  # Extract x and z coordinates
  x_coords = [point['x'] for point in all_points]
  z_coords = [point['z'] for point in all_points]

  # Determine the bounds of the grid
  min_x, max_x = min(x_coords), max(x_coords)
  min_z, max_z = min(z_coords), max(z_coords)

  # Calculate grid dimensions
  grid_height = int((max_x - min_x) / resolution) + 1
  grid_width = int((max_z - min_z) / resolution) + 1

  # Initialize the occupancy grid (0 for free space, 1 for occupied)
  occupancy_grid = np.zeros((grid_height, grid_width), dtype=int)
  # Draw the kitchen and serving room polygons on the grid
  draw_polygon_on_grid(kitchen_polygon, occupancy_grid, 1, min_x, min_z, resolution)
  draw_polygon_on_grid(serving_room_polygon, occupancy_grid, 1, min_x, min_z, resolution)

  return {
      'grid': occupancy_grid,
      'min_x': min_x,
      'max_x': max_x,
      'min_z': min_z,
      'max_z': max_z,
      'resolution': resolution
  }

kitchen = restaurant['rooms']['kitchen']['polygon']
serving_room = restaurant['rooms']['servingroom']['polygon']

# Get base grid
grid = get_occupancy_grid(kitchen, serving_room)

door = restaurant['doors']['door1']['position']
door = restaurant['doors']['door1']['position']
door_start_grid_x, door_start_grid_z = world_to_grid(door[0]['x'], door[0]['z'], grid['min_x'], grid['min_z'], grid['resolution'])
door_end_grid_x, door_end_grid_z = world_to_grid(door[1]['x'], door[1]['z'], grid['min_x'], grid['min_z'], grid['resolution'])
# Draw the door as free space (0)
draw_line(grid['grid'], door_start_grid_x, door_start_grid_z, door_end_grid_x, door_end_grid_z, 0)

# draw the containers as blocked spaces

containers = restaurant['objects']
for container in containers:
  rectangle = Polygon([(point['x'], point['z']) for point in container['polygon']])
  # inter_x, inter_z = world_to_grid(container['position']['x'], container['position']['z'], grid['min_x'], grid['min_z'], grid['resolution'])
  # grid['grid'][inter_z, inter_x] = 1
  update_occupancy_grid_with_rectangles(grid['grid'], rectangle, grid['min_x'], grid['min_z'], grid['resolution'], 1)

plt.figure(figsize=(8, 8))
plt.imshow(grid['grid'], cmap='Greys')
plt.xlabel('X Coordinate')
plt.ylabel('Z Coordinate')
plt.title('Occupancy Grid with Merged Rooms and Door')
plt.show()

# %%
from shapely.geometry import Point
import math

# Function to inflate polygons by a specified distance
def inflate_polygon(polygon, distance):
    return polygon.buffer(distance)

def euclidean_distance(point1, point2):
    return math.sqrt((point1[0] - point2[0])**2 + (point1[1] - point2[1])**2)

# Function to get points around a single container that are not occupied
def get_unoccupied_points_around_container(occupancy_grid, min_x, min_z,
                                           resolution, container,
                                           inflation_distance, mother_poly):
    occupancy_grid = gridmap.utils.inflate_grid(occupancy_grid, 2)
    unoccupied_points = []
    grid_height, grid_width = occupancy_grid.shape

    original_polygon = Polygon([(point['x'], point['z']) for point in container['polygon']])
    inflated_container = inflate_polygon(original_polygon, 0.2)
    # Inflate the container polygon
    inflated_polygon = inflate_polygon(original_polygon, inflation_distance)

    # Get the bounds of the inflated polygon
    min_x_inf, min_z_inf, max_x_inf, max_z_inf = inflated_polygon.bounds

    # Calculate grid indices for the inflated polygon bounds
    grid_min_x_inf, grid_min_z_inf = world_to_grid(min_x_inf, min_z_inf,
                                                   min_x, min_z, resolution)
    grid_max_x_inf, grid_max_z_inf = world_to_grid(max_x_inf, max_z_inf,
                                                   min_x, min_z, resolution)

    # Iterate over the grid cells within the inflated polygon bounds
    for grid_x in range(max(0, grid_min_x_inf),
                        min(grid_height, grid_max_x_inf + 1)):
        for grid_z in range(max(0, grid_min_z_inf),
                            min(grid_width, grid_max_z_inf + 1)):
            # if container['assetId'] == 'stable3':              
            #   print(grid_x, grid_z)
            world_x = min_x + grid_x * resolution
            world_z = min_z + grid_z * resolution
            point = Point(world_x, world_z)

            # Check if the point is within the inflated polygon, not within the original polygon, and not occupied
            # if container['assetId'] == 'stable3':
            #   print(inflated_polygon.contains(point))
            #   print(mother_poly.contains(point))
            #   print(inflated_container.contains(point))
            #   print(occupancy_grid[grid_x, grid_z])
            if inflated_polygon.contains(point) and mother_poly.contains(
                point) and (
                    not inflated_container.contains(
                        point)):
                gx, gz = world_to_grid(world_x, world_z, min_x, min_z, resolution)
                if occupancy_grid[gx, gz] == 1:
                  continue
                unoccupied_points.append((world_x, world_z))
            # if occupancy_grid[grid_x, grid_z] == 0:
            #   gx, gz = world_to_grid(world_x, world_z, min_x, min_z, resolution)
            #   if occupancy_grid[gx, gz] == 1:
            #     print(gx, gz)
            #     print(grid_x, grid_z)
            #     print(occupancy_grid[gx, gz])
            # unoccupied_points.append((world_x, world_z))

    p1 = (inflated_container.centroid.x, inflated_container.centroid.y)
    min_dis = float('inf')
    c_point = ()
    for p2 in unoccupied_points:
        dis = euclidean_distance(p1, p2)
        if (dis < min_dis):
            min_dis = dis
            c_point = p2
    # return c_point
    # if len(unoccupied_points) == 0:
    #   raise NotImplementedError
    return [c_point]

# Example usage for a single container
inflation_distance = 0.3  # Inflate by 1 unit

# Create a dictionary to store unoccupied points for each container
unoccupied_points_per_container = {}

for i, container in enumerate(containers):
    # print(container)
    mother_poly = Polygon([(point['x'], point['z']) for point in serving_room])
    # print(mother_poly)
    if container['loc'] == 'kitchen':
        mother_poly = Polygon([(point['x'], point['z'])
                                for point in kitchen])
    unoccupied_points_per_container[f'{container["assetId"]}'] = get_unoccupied_points_around_container(
        grid['grid'], grid['min_x'], grid['min_z'], grid['resolution'], container, inflation_distance, mother_poly
    )

# Plot the results
plt.figure(figsize=(8, 8))
plt.imshow(grid['grid'], cmap='Greys')
plt.xlabel('X Coordinate')
plt.ylabel('Z Coordinate')
plt.title('Unoccupied Points Around Inflated Containers')

# Plot the unoccupied points for each container
colors = ['red', 'blue', 'green', 'orange', 'purple']  # Add more colors if you have more containers
for i, (container_name, unoccupied_points) in enumerate(unoccupied_points_per_container.items()):
    # print(container_name, len(unoccupied_points))
    if unoccupied_points:  # Check if there are any points to plot
        unoccupied_points = [world_to_grid(point[1], point[0], grid['min_x'], grid['min_z'], grid['resolution']) for point in unoccupied_points]
        # print(unoccupied_points)
        unoccupied_x, unoccupied_z = zip(*unoccupied_points)
        # unoccupied_x = [world_to_grid(door[0]['x'], door[0]['z'], grid['min_x'], grid['min_z'], grid['resolution']) for x in unoccupied_x]
        plt.scatter(unoccupied_x, unoccupied_z, color=colors[i % len(colors)], s=1, label=container_name)

# plt.legend()
plt.show()

print(grid['grid'].shape)
# Out:
# (102, 102)
